# %% [markdown]
# ### Exploration of eBay Car sales data

# %% [markdown]
# In this project we are going to explore a dataset of used cars from eBay Kleinanzeigen a German Car website.The data set was web scrapped and posted in kaggle and its available [here](https://data.world/data-society/used-cars-data)

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv('autos.csv', encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %% [markdown]
# When checking the information of the data set,we notice the data has 20 columns and some of the columns are in camelcase as to the pythons standards snakecase.

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
#displaying the column names
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
#renaming the column headers
autos.rename({
    'yearOfRegistration': 'registration_year',
    'monthOfRegistration': 'registration_month',
    'notRepairedDamage': 'unrepaired_damage',
    'dateCreated': 'ad_created',  
    'dateCrawled': 'date_crawled',
    'offerType': 'offer_type',
    'vehicleType': 'vehicle_type',
    'powerPS': 'power_ps',
    'fuelType': 'fuel_type',
    'nrOfPictures': 'num_pictures',
    'postalCode': 'postal_code',
    'lastSeen' : 'last_seen'
    
},axis=1, inplace=True)

# %%
autos.head(5)
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'num_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# ##  Data Exploration and cleaning

# %% [markdown]
# We shall start by running function to have an overview of the dataset to check the parts that needs cleaning

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-08 10:40:35  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %% [markdown]
# In the dataset we notice that ***seller*** and ***offer_type*** columns the values appear to the same and the num_pictures columns the data needs to be investigated further

# %%
autos["num_pictures"].value_counts()
# Out:
# 0    50000
# Name: num_pictures, dtype: int64

# %% [markdown]
# The picture column seems to have zero values for all the rows.We shall drop this  and ***seller*** and ***offer_type*** columns

# %%
autos = autos.drop(["num_pictures", "seller", "offer_type"], axis=1)

# %% [markdown]
# We are also going to clean the ***price*** column and ***odometer*** which is stored as text.

# %%
autos["price"] = autos["price"].str.replace('$','').str.replace(',','').astype(float)
autos["price"].head()
# Out:
# 0    5000.0
# 1    8500.0
# 2    8990.0
# 3    4350.0
# 4    1350.0
# Name: price, dtype: float64

# %%
autos["odometer"] = autos["odometer"].str.replace(',','').str.replace('km','').astype(float)
autos["odometer"].head()
# Out:
# 0    150000.0
# 1    150000.0
# 2     70000.0
# 3     70000.0
# 4    150000.0
# Name: odometer, dtype: float64

# %%
#renaming odometer column
autos.rename({'odometer': 'odometer_km'},axis=1,inplace = True)
autos.columns
# Out:
# Index(['date_crawled', 'name', 'price', 'abtest', 'vehicle_type',
#        'registration_year', 'gearbox', 'power_ps', 'model', 'odometer_km',
#        'registration_month', 'fuel_type', 'brand', 'unrepaired_damage',
#        'ad_created', 'postal_code', 'last_seen'],
#       dtype='object')

# %% [markdown]
# ### Exploring the Price column

# %%
print(autos['price'].unique().shape)
print(autos['price'].describe())
print(autos['price'].value_counts().sort_index(ascending=True).head(20))
# Out:
# (2357,)
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64
# 0.0     1421
# 1.0      156
# 2.0        3
# 3.0        1
# 5.0        2
# 8.0        1
# 9.0        1
# 10.0       7
# 11.0       2
# 12.0       3
# 13.0       2
# 14.0       1
# 15.0       2
# 17.0       3
# 18.0       1
# 20.0       4
# 25.0       5
# 29.0       1
# 30.0       7
# 35.0       1
# Name: price, dtype: int64

# %%
#the top 20 prices for the cars
print(autos['price'].value_counts().sort_index(ascending=False).head(20))
# Out:
# 99999999.0    1
# 27322222.0    1
# 12345678.0    3
# 11111111.0    2
# 10000000.0    1
# 3890000.0     1
# 1300000.0     1
# 1234566.0     1
# 999999.0      2
# 999990.0      1
# 350000.0      1
# 345000.0      1
# 299000.0      1
# 295000.0      1
# 265000.0      1
# 259000.0      1
# 250000.0      1
# 220000.0      1
# 198000.0      1
# 197000.0      1
# Name: price, dtype: int64

# %% [markdown]
# When observing our data find that the highest price is 99999999 and the data is raising steadily updto 350,000.

# %%
#fildtering the dataset to include only data between 1 and 350000
autos[autos['price'].between(1,351000)].head(5)
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
# returns unique values in price column
print(autos["price"].unique().shape)
# Out:
# (2357,)

# %%
# returns the counts of top 5 most common price values
print(autos["price"].value_counts().head())
# Out:
# 0.0       1421
# 500.0      781
# 1500.0     734
# 2500.0     643
# 1200.0     639
# Name: price, dtype: int64

# %%
#checking the values for the odometer
autos["odometer_km"].value_counts()
# Out:
# 150000.0    32424
# 125000.0     5170
# 100000.0     2169
# 90000.0      1757
# 80000.0      1436
# 70000.0      1230
# 60000.0      1164
# 50000.0      1027
# 5000.0        967
# 40000.0       819
# 30000.0       789
# 20000.0       784
# 10000.0       264
# Name: odometer_km, dtype: int64

# %%
print(autos['odometer_km'].unique().shape)
print(autos['odometer_km'].describe())
print(autos['odometer_km'].value_counts().sort_index(ascending=True).head(20))
# Out:
# (13,)
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64
# 5000.0        967
# 10000.0       264
# 20000.0       784
# 30000.0       789
# 40000.0       819
# 50000.0      1027
# 60000.0      1164
# 70000.0      1230
# 80000.0      1436
# 90000.0      1757
# 100000.0     2169
# 125000.0     5170
# 150000.0    32424
# Name: odometer_km, dtype: int64

# %%
#getting the lowest 20 odometer reading
print(autos['odometer_km'].value_counts().sort_index(ascending=False).head(20))
# Out:
# 150000.0    32424
# 125000.0     5170
# 100000.0     2169
# 90000.0      1757
# 80000.0      1436
# 70000.0      1230
# 60000.0      1164
# 50000.0      1027
# 40000.0       819
# 30000.0       789
# 20000.0       784
# 10000.0       264
# 5000.0        967
# Name: odometer_km, dtype: int64

# %% [markdown]
# ### Exploring the date Columns

# %% [markdown]
# There are a number of columns with date information:
#
# ***date_crawled***
# ***ad_created***
# ***last_seen***
# These are a combination of dates that were crawled, and dates with meta-information from the crawler. The non-registration dates are stored as strings.

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
(autos["date_crawled"]
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
        )
# Out:
# 2016-03-05    0.02538
# 2016-03-06    0.01394
# 2016-03-07    0.03596
# 2016-03-08    0.03330
# 2016-03-09    0.03322
# 2016-03-10    0.03212
# 2016-03-11    0.03248
# 2016-03-12    0.03678
# 2016-03-13    0.01556
# 2016-03-14    0.03662
# 2016-03-15    0.03398
# 2016-03-16    0.02950
# 2016-03-17    0.03152
# 2016-03-18    0.01306
# 2016-03-19    0.03490
# 2016-03-20    0.03782
# 2016-03-21    0.03752
# 2016-03-22    0.03294
# 2016-03-23    0.03238
# 2016-03-24    0.02910
# 2016-03-25    0.03174
# 2016-03-26    0.03248
# 2016-03-27    0.03104
# 2016-03-28    0.03484
# 2016-03-29    0.03418
# 2016-03-30    0.03362
# 2016-03-31    0.03192
# 2016-04-01    0.03380
# 2016-04-02    0.03540
# 2016-04-03    0.03868
# 2016-04-04    0.03652
# 2016-04-05    0.01310
# 2016-04-06    0.00318
# 2016-04-07    0.00142
# Name: date_crawled, dtype: float64

# %% [markdown]
# It looks like the site was crawled daily over roughly a one month period in March and April 2016. The distribution of listings crawled on each day is roughly uniform.

# %%
(autos["ad_created"]
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
        )
# Out:
# 2015-06-11    0.00002
# 2015-08-10    0.00002
# 2015-09-09    0.00002
# 2015-11-10    0.00002
# 2015-12-05    0.00002
#                ...
# 2016-04-03    0.03892
# 2016-04-04    0.03688
# 2016-04-05    0.01184
# 2016-04-06    0.00326
# 2016-04-07    0.00128
# Name: ad_created, Length: 76, dtype: float64

# %% [markdown]
# The crawler recorded the date it last saw any listing, which allows us to determine on what day a listing was removed, presumably because the car was sold.
#
# The last three days contain a disproportionate amount of 'last seen' values. Given that these are 6-10x the values from the previous days, it's unlikely that there was a massive spike in sales, and more likely that these values are to do with the crawling period ending and don't indicate car sales.

# %%
(autos["last_seen"]
        .str[:10]
        .value_counts(normalize=True, dropna=False)
        .sort_index()
        )
# Out:
# 2016-03-05    0.00108
# 2016-03-06    0.00442
# 2016-03-07    0.00536
# 2016-03-08    0.00760
# 2016-03-09    0.00986
# 2016-03-10    0.01076
# 2016-03-11    0.01252
# 2016-03-12    0.02382
# 2016-03-13    0.00898
# 2016-03-14    0.01280
# 2016-03-15    0.01588
# 2016-03-16    0.01644
# 2016-03-17    0.02792
# 2016-03-18    0.00742
# 2016-03-19    0.01574
# 2016-03-20    0.02070
# 2016-03-21    0.02074
# 2016-03-22    0.02158
# 2016-03-23    0.01858
# 2016-03-24    0.01956
# 2016-03-25    0.01920
# 2016-03-26    0.01696
# 2016-03-27    0.01602
# 2016-03-28    0.02086
# 2016-03-29    0.02234
# 2016-03-30    0.02484
# 2016-03-31    0.02384
# 2016-04-01    0.02310
# 2016-04-02    0.02490
# 2016-04-03    0.02536
# 2016-04-04    0.02462
# 2016-04-05    0.12428
# 2016-04-06    0.22100
# 2016-04-07    0.13092
# Name: last_seen, dtype: float64

# %% [markdown]
# There is a large variety of ad created dates. Most fall within 1-2 months of the listing date, but a few are quite old, with the oldest at around 9 months.

# %%
autos['registration_year'].describe()
# Out:
# count    50000.000000
# mean      2005.073280
# std        105.712813
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The year that the car was first registered will likely indicate the age of the car. Looking at this column, we note some odd values. The minimum value is 1000, long before cars were invented and the maximum is 9999, many years into the future.

# %% [markdown]
# ### Incorrect Registration Year Data

# %% [markdown]
# Because a car can't be first registered before the listing was seen, any vehicle with a registration year above 2016 is definitely inaccurate. Determining the earliest valid year is more difficult. Realistically, it could be somewhere in the first few decades of the 1900s.
#
# One option is to remove the listings with these values. Let's determine what percentage of our data has invalid values in this column:

# %%
autos = autos[autos["registration_year"].between(1900, 2016)]

# %%
autos["registration_year"].value_counts(normalize=True).head(10)
# Out:
# 2000    0.069834
# 2005    0.062776
# 1999    0.062464
# 2004    0.056988
# 2003    0.056779
# 2006    0.056384
# 2001    0.056280
# 2002    0.052740
# 1998    0.051074
# 2007    0.047972
# Name: registration_year, dtype: float64

# %% [markdown]
# Most of the cars were registered the first 20 years

# %% [markdown]
# ### Exploring Price by Brand

# %%
autos['brand'].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini', 'toyota', 'dacia', 'nissan',
#        'jeep', 'saab', 'volvo', 'mitsubishi', 'jaguar', 'fiat', 'skoda',
#        'subaru', 'kia', 'citroen', 'chevrolet', 'hyundai', 'honda',
#        'daewoo', 'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'lada',
#        'rover', 'daihatsu', 'lancia'], dtype=object)

# %%
print(autos['brand'].value_counts(normalize=True))
# Out:
# volkswagen        0.212126
# bmw               0.110019
# opel              0.108166
# mercedes_benz     0.095361
# audi              0.086387
# ford              0.069793
# renault           0.047347
# peugeot           0.029524
# fiat              0.025860
# seat              0.018177
# skoda             0.016032
# mazda             0.015137
# nissan            0.015095
# citroen           0.013929
# smart             0.013909
# toyota            0.012472
# sonstige_autos    0.010952
# hyundai           0.009848
# volvo             0.009245
# mini              0.008641
# mitsubishi        0.008141
# honda             0.007850
# kia               0.007100
# alfa_romeo        0.006621
# porsche           0.006101
# suzuki            0.005913
# chevrolet         0.005705
# chrysler          0.003665
# dacia             0.002561
# daihatsu          0.002561
# jeep              0.002249
# subaru            0.002186
# land_rover        0.002040
# saab              0.001603
# ...

# %% [markdown]
# When observing the data set,German models form the top 5 brands in the list with Volkswagen form the largest percentage.There are also several listings that have an insignificant percentage in the brands.As we are going to focus on brands that take 5% of the brands.

# %%
brand_counts = autos["brand"].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > .05].index
print(common_brands)
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
#getting the mean prices for each brand
brand_mean_prices = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices
# Out:
# {'volkswagen': 6516,
#  'bmw': 8334,
#  'opel': 5252,
#  'mercedes_benz': 30317,
#  'audi': 9093,
#  'ford': 7263}

# %% [markdown]
# When observing the prices for the 5 brands,mercedes,bmw and audi are among the most expensive
# Volkswagen which is the most popular happens to have a lower price and thats why its preferred.
# Ford and Opel are less expensive

# %%
bmp_series = pd.Series(brand_mean_prices)
pd.DataFrame(bmp_series, columns=["mean_price"])
# Out:
#                mean_price
# volkswagen           6516
# bmw                  8334
# opel                 5252
# mercedes_benz       30317
# audi                 9093
# ford                 7263

# %%
brand_mean_mileage = {}

for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_mileage = brand_only['odometer_km'].mean()
    brand_mean_mileage[brand] = int(mean_mileage)
    
mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending=False)
mean_prices = pd.Series(brand_mean_prices).sort_values(ascending=False)

# %%
df = pd.Series(brand_mean_mileage)
pd.DataFrame(df,columns=["mean_mileage"])
# Out:
#                mean_mileage
# volkswagen           128730
# bmw                  132434
# opel                 129227
# mercedes_benz        130860
# audi                 129287
# ford                 124046

# %%
brand_info = pd.DataFrame(mean_mileage,columns=['mean_mileage'])
brand_info
# Out:
#                mean_mileage
# bmw                  132434
# mercedes_benz        130860
# audi                 129287
# opel                 129227
# volkswagen           128730
# ford                 124046

# %%
brand_info["mean_price"] = mean_prices
brand_info
# Out:
#                mean_mileage  mean_price
# bmw                  132434        8334
# mercedes_benz        130860       30317
# audi                 129287        9093
# opel                 129227        5252
# volkswagen           128730        6516
# ford                 124046        7263

# %% [markdown]
# ### Analysis by car brand and Model Combinations

# %%
autos_by_brandmodel = autos.groupby(["brand", "model"])["brand"].count()
pd.set_option('display.max_rows', 291) #used to force Jupyter notebook to show all the values
print(autos_by_brandmodel)
# Out:
# brand          model
# alfa_romeo     145                      4
#                147                     80
#                156                     92
#                159                     33
#                andere                  60
#                spider                  33
# audi           100                     59
#                200                      1
#                80                     209
#                90                       9
#                a1                      82
#                a2                      43
#                a3                     838
#                a4                    1265
#                a5                     126
#                a6                     814
#                a8                      72
#                andere                 219
#                q3                      28
#                q5                      62
#                q7                      40
#                tt                     147
# ...

# %%
autos_by_brandmodel_max = autos_by_brandmodel.sort_values()
print(autos_by_brandmodel_max)
# Out:
# brand          model
# ford           b_max                    1
# rover          rangerover               1
#                discovery                1
# bmw            i3                       1
# audi           200                      1
# rover          freelander               2
# lancia         kappa                    2
# dacia          andere                   2
# volvo          v60                      3
# daihatsu       charade                  3
# lada           samara                   4
# alfa_romeo     145                      4
# daihatsu       materia                  4
# fiat           croma                    4
# land_rover     andere                   4
# lancia         delta                    5
# dacia          lodgy                    5
# saab           9000                     5
# land_rover     range_rover_evoque       5
# chrysler       crossfire                6
# volkswagen     amarok                   6
# seat           exeo                     6
# ...

# %% [markdown]
# ### Conclusions

# %% [markdown]
# * The vast majority of cars with odometer values are concentrated on mileages over 150.000 KM
#
# * There is a concentration of crawled ads on the March 20s dates, which suggests Easter is a high selling season
#
# * Most of the cars in the database have a registration year in the early 2000s
#
# * Mid-end brands stay consistently on the 2.500 to 3.500 range, and high-end brands stay consistently over 8.000 euros
#
# * High-end brands have the most mileage, however they keep the highest price. This is an indicator of slow devaluation
